# %%
# !apt-get install p7zip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# !wget https://github.com/samsungnlp/smiler/raw/main/smiler_corpora_v1.0_part1.7z
# !7z e smiler_corpora_v1.0_part1.7z
# Out:
# --2024-05-02 05:11:16--  https://github.com/samsungnlp/smiler/raw/main/smiler_corpora_v1.0_part1.7z
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/samsungnlp/smiler/main/smiler_corpora_v1.0_part1.7z [following]
# --2024-05-02 05:11:16--  https://raw.githubusercontent.com/samsungnlp/smiler/main/smiler_corpora_v1.0_part1.7z
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28929993 (28M) [application/octet-stream]
# Saving to: ‘smiler_corpora_v1.0_part1.7z’
#
# smiler_corpora_v1.0 100%[===================>]  27.59M  11.5MB/s    in 2.4s
#
# 2024-05-02 05:11:19 (11.5 MB/s) - ‘smiler_corpora_v1.0_part1.7z’ saved [28929993/28929993]
#
# /bin/bash: line 1: 7z: command not found

# %%
SMILER_TRANSLATE = {
    "en": {
        "birth-place": "birth place",
        "eats": "eats",
        "event-year": "event year",
        "first-product": "first product",
        "from-country": "from country",
        "has-author": "has author",
        "has-child": "has child",
        "has-edu": "has education",
        "has-genre": "has genre",
        "has-height": "has height",
        "has-highest-mountain": "has highest mountain",
        "has-length": "has length",
        "has-lifespan": "has lifespan",
        "has-nationality": "has nationality",
        "has-occupation": "has occupation",
        "has-parent": "has parent",
        "has-population": "has population",
        "has-sibling": "has sibling",
        "has-spouse": "has spouse",
        "has-tourist-attraction": "has tourist attraction",
        "has-type": "has type",
        "has-weight": "has weight",
        "headquarters": "headquarters",
        "invented-by": "invented by",
        "invented-when": "invented when",
        "is-member-of": "is member of",
        "is-where": "located in",
        "loc-leader": "location leader",
        "movie-has-director": "movie has director",
        "no_relation": "no relation",
        "org-has-founder": "organization has founder",
        "org-has-member": "organization has member",
        "org-leader": "organization leader",
        "post-code": "post code",
        "starring": "starring",
        "won-award": "won award",
    },
    "fr": {
        "birth-place": "lieu de naissance",
        "eats": "mange",
        "event-year": "année de l'événement",
        "first-product": "premier produit",
        "from-country": "du pays",
        "has-author": "a pour auteur",
        "has-child": "a pour enfant",
        "has-edu": "a une éducation",
        "has-genre": "a un genre",
        "has-height": "a une taille",
        "has-highest-mountain": "a la plus haute montagne",
        "has-length": "a une longueur",
        "has-lifespan": "a une durée de vie",
        "has-nationality": "a une nationalité",
        "has-occupation": "a une occupation",
        "has-parent": "a un parent",
        "has-population": "a une population",
        "has-sibling": "a un frère ou une sœur",
        "has-spouse": "a un conjoint",
        "has-tourist-attraction": "a une attraction touristique",
        "has-type": "a un type",
        "has-weight": "a un poids",
        "headquarters": "siège social",
        "invented-by": "inventé(e) par",
        "invented-when": "inventé(e) quand",
        "is-member-of": "est membre de",
        "is-where": "est situé(e) à",
        "loc-leader": "leader local",
        "movie-has-director": "film réalisé par",
        "no_relation": "aucune relation",
        "org-has-founder": "organisation fondée par",
        "org-has-member": "organisation a pour membre",
        "org-leader": "leader de l'organisation",
        "post-code": "code postal",
        "starring": "mettant en vedette",
        "won-award": "a remporté un prix"
    },
    "ru": {
        "birth-place": "место рождения",
        "eats": "ест",
        "event-year": "год события",
        "first-product": "первый продукт",
        "from-country": "из страны",
        "has-author": "имеет автора",
        "has-child": "имеет ребенка",
        "has-edu": "имеет образование",
        "has-genre": "имеет жанр",
        "has-height": "имеет рост",
        "has-highest-mountain": "имеет самую высокую гору",
        "has-length": "имеет длину",
        "has-lifespan": "имеет продолжительность жизни",
        "has-nationality": "имеет национальность",
        "has-occupation": "имеет профессию",
        "has-parent": "имеет родителя",
        "has-population": "имеет население",
        "has-sibling": "имеет брата или сестру",
        "has-spouse": "имеет супруга(у)",
        "has-tourist-attraction": "имеет туристическую достопримечательность",
        "has-type": "имеет тип",
        "has-weight": "имеет вес",
        "headquarters": "штаб-квартира",
        "invented-by": "изобретен(а) кем",
        "invented-when": "изобретен(а) когда",
        "is-member-of": "является членом",
        "is-where": "находится в",
        "loc-leader": "лидер местности",
        "movie-has-director": "фильм имеет режиссера",
        "no_relation": "нет отношения",
        "org-has-founder": "организация имеет основателя",
        "org-has-member": "организация имеет члена",
        "org-leader": "лидер организации",
        "post-code": "почтовый индекс",
        "starring": "с участием",
        "won-award": "получил(а) награду"
    }
}

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, AutoModelForCausalLM 
class args:
    tgt_num = 200 # First 200 examples from the target language
    src_num = 5 # NO examples from the source language
    max_new_tokens = 100
    temperature = 0.6
    device="cuda:0"
    l1 = "en"
    l2 = "fr"
    l3 = "ru"

tokenizer = AutoTokenizer.from_pretrained("bigscience/mt0-large")
model = AutoModelForSeq2SeqLM.from_pretrained("bigscience/mt0-large").to(args.device)

# %%
## Script for creating a prompt for the user to enter a number
import json
import argparse
import csv
import os
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
# XGLMTokenizer, XGLMForCausalLM,
from tqdm import tqdm
import re
import random
relations = set()

dir_path=""
prompt_template_cross = {
    "en": """Consider a domain where only the following relations can exist between any two entities:

{}

Given the following examples,

{}

Given,
{}

{}

{}
    """,
    "fr":"""Considérez un domaine où seules les relations suivantes peuvent exister entre deux entités : 

{}

Étant donné les exemples suivants,

{}

Given,
{}

{}

{}
    """,
    "ru":"""Рассмотрим область, где могут существовать только следующие отношения между любыми двумя сущностями: 

{}

Учитывая следующие примеры,

{}

Given,
{}

{}

{}
    """
}

statements={
    "en":"Statement",
    "fr":"Déclaration",
    "ru":"Утверждение"
}

decs_relation = {
    "en":"{} best describes the relation between {} and {}",
    "fr":"{} décrit le mieux la relation entre {} et {}",
    "ru":"{} лучше всего описывает отношение между {} и {}"
}

l2_query_instruct={
    "en":"What relation best describes the relation between {} and {} from the list of relations given above?",
    "fr":"Quelle relation décrit le mieux la relation entre {} et {} à partir de la liste des relations données ci-dessus?",
    "ru":"Какое отношение лучше всего описывает отношение между {} и {} из списка отношений, указанных выше?"
}

task_alignment={
    "en":"In English {} means {}",
    "fr":"En français, {} signifie {}",
    "ru":"По-русски {} означает {}"
}



def create_examples(src, tgt, num):
    with open(dir_path + f"{src}_corpora_train.tsv", "r") as f:
        reader = list(csv.reader(f, delimiter="\t"))
        random.shuffle(reader)
        examples = ""
        for i, row in enumerate(reader):
            if i < 1:
                continue
            if i > num:
                break
            sen = row[4]
            sen = sen.replace("<e1>", "").replace("</e1>", "").replace("<e2>", "").replace("</e2>", "")
            e1 = row[4].split("<e1>")[1].split("</e1>")[0]
            e2 = row[4].split("<e2>")[1].split("</e2>")[0]
            e1="{{"+e1+"}}"
            e2="{{"+e2+"}}"
            sen = "{{"+sen+"}}"
            # rel = "{{"+SMILER_TRANSLATE[src][row[3]]+"}}"
            rel = row[3]
            relations.add(rel)

            rel_decs = decs_relation[src].format(rel,e1,e2)
            examples += "{}: {}\n{}\n\n".format(statements[src],sen,rel_decs)

        return examples



def inference(prompt, max_new_tokens=args.max_new_tokens, temperature=args.temperature):


    model_inputs = tokenizer([prompt], return_tensors="pt").to(args.device)

    # For removal of input string from the output string
    input_ids_cutoff = model_inputs.input_ids.size(dim=1)

    generated_ids = model.generate(**model_inputs,
                                   max_new_tokens=max_new_tokens,
                                   top_p = 1,
                                   temperature = temperature,
                                   # num_beams=5,
                                   do_sample=True,
                                   pad_token_id=tokenizer.eos_token_id)

    completion = tokenizer.decode(
    generated_ids[0],
    skip_special_tokens=True)

    return completion


def create_rel_vocab(src_lang, tgt_lang, src_num, tgt_num):


    # Iterate src
    # with open(dir_path + f"{src_lang}_corpora_train.tsv", "r") as f:
    #     reader = csv.reader(f, delimiter="\t")
    #     for i, row in enumerate(reader):
    #         if i < 1:
    #             continue
    #         if i > src_num:
    #             break
    #         relations.add(f"{row[3]}")

    # Iterate tgt
    try:
        with open(dir_path + f"{tgt_lang}_corpora_test.tsv", "r") as f:
            reader = csv.reader(f, delimiter="\t")
            for i, row in enumerate(reader):
                if i < 1:
                    continue
                if i > tgt_num:
                    break
                # rel = "{{"+SMILER_TRANSLATE[src_lang][row[3]]+"}}"
                rel = row[3]
                relations.add(f'{rel}')
                # relations.add(f'"{row[3]}"')
    except Exception:
        print(src_lang, tgt_lang, row[3])
        raise Exception()

    return relations


def main():
    global relations
    for lang1 in [args.l1, args.l2, args.l3]:
        for lang2 in [args.l2, args.l1, args.l3]:
            actual_result = []
            gen_result = []
            relations = set()

            if lang1 == lang2:
                continue

            # Create relation vocabulary
            choices = create_rel_vocab(lang1, lang2, args.src_num, args.tgt_num)

            # If not zero-shot, create examples
            eg = create_examples(lang1, lang2, args.src_num)

            os.makedirs(f"{lang1}_{lang2}", exist_ok=True)
            # Create prompt for each example and save it
            with open(dir_path + f"{lang2}_corpora_test.tsv", "r") as f:
                reader = csv.reader(f, delimiter="\t")
                for i, row in enumerate(reader):
                    if i < 1:
                        continue
                    if i > args.tgt_num:
                        break
                    # if f'"{SMILER_TRANSLATE[lang2][row[3]]}"' not in choices:
                    # # if f'"{row[3]}"' not in choices:
                    #     raise ValueError(f"Relation {row[3]} not in the relation vocabulary {lang2}")

                    sen = row[4]
                    sen = sen.replace("<e1>", "").replace("</e1>", "").replace("<e2>", "").replace("</e2>", "")
                    e1 = row[4].split("<e1>")[1].split("</e1>")[0]
                    e2 = row[4].split("<e2>")[1].split("</e2>")[0]
                    sen = "{{"+sen+"}}"
                    e1 = "{{"+e1+"}}"
                    e2 = "{{"+e2+"}}"
                    # prompt = prompt_src.format(sen, e1, e2, "\n".join(choices))
                    crt_statement = statements[lang2]+": "+ sen + "\n"
                    tgt_query = l2_query_instruct[lang2].format(e1,e2)
                    aligned_targets = "\n".join(task_alignment[lang2].format("{{"+SMILER_TRANSLATE[lang1][re.sub(r'[{}]', '', ch_ )]+"}}", "{{"+SMILER_TRANSLATE[lang2][re.sub(r'[{}]', '', ch_ )]+"}}") for ch_ in choices)
                    prompt = prompt_template_cross[lang1].format("\n".join("{{"+SMILER_TRANSLATE[lang1][XYZ]+"}}" for XYZ in choices), eg,aligned_targets ,crt_statement,tgt_query)
                    
                    result = inference(prompt)
                    # Clean the result
                    result = re.sub(r"[!@#$%^&*()_+\-=[\]{};':,.<>/?\\|~]", "", result)
                    # Also remove all quotes
                    result = result.replace('"', "").replace("'", "").replace("`", "")
                    # result = next((key for key, value in SMILER_TRANSLATE[lang2].items() if value == result), result)

                    print(row[3], result)
                    
                    with open(f"{lang1}_{lang2}/prompt_{i}.txt", "w") as f:
                        f.write(prompt)

                    actual_result.append(SMILER_TRANSLATE[lang1][row[3]])
                    gen_result.append(result)

            df = pd.DataFrame({"actual": actual_result, "generated": gen_result})
            df.to_csv(f"{lang1}_{lang2}/results.tsv", sep="\t", index=False)
            print(f"Results saved for {lang1} to {lang2}")


main()
# Out:
# birth-place hastype
# has-type hastype
# movie-has-director hastype
# has-occupation hasoccupation
# movie-has-director hasoccupation
# birth-place instance of
# has-genre Yes
# birth-place hastype
# birth-place The relation between Vickie Ree Principal and entrepreneur
# birth-place No
# has-genre hastype
# birth-place hastype
# movie-has-director hasoccupation
# has-occupation No
# has-type hastype
# birth-place No
# has-author hastype
# has-occupation hasoccupation
# has-occupation hastype
# from-country hastype
# birth-place Where did Niels Viggo Bentzon die
# has-type hastype
# birth-place Where is the name of the political party
# is-where No
# is-where hastype
# movie-has-director instance of
# is-where hastype
# birth-place where is Victoria Principal born
# movie-has-director hastype
# has-author hastype
# has-genre No
# org-has-member hastype
# has-author instance of
# has-occupation hasoccupation
# event-year instance of
# headquarters hastype
# has-type hastype
# is-where hastype
# birth-place hasoccupation
# movie-has-director hasoccupation
# has-parent No
# has-occupation hastype
# movie-has-director hastype
# is-where country
# is-where hastype
# is-where hastype
# birth-place Where did Jochen Rindt die
# has-genre hastype
# is-where hastype
# is-where hastype
# movie-has-director hasoccupation
# birth-place No
# movie-has-director instance of
# movie-has-director hasoccupation
# is-where hastype
# has-occupation hastype
# birth-place hastype
# birth-place No
# birth-place haveoccupation
# birth-place Yes
# has-author hasoccupation
# movie-has-director hastype
# from-country where is narrower
# birth-place No
# birth-place hastype
# birth-place hasspouse
# birth-place hastype
# has-type hastype
# birth-place headquarters
# birth-place where is Walter Goehr from
# movie-has-director hasoccupation
# is-member-of hasspouse
# birth-place Location
# movie-has-director No
# has-type hastype
# birth-place hastype
# has-genre hastype
# has-occupation Hastype
# has-genre Hastype
# birth-place No
# birth-place hastype
# is-where No
# birth-place Yes
# birth-place hastype
# has-occupation hasoccupation
# has-occupation hasoccupation
# has-genre No
# birth-place No
# birth-place hastype
# has-genre hastype
# birth-place relationship
# birth-place hastype
# birth-place hasoccupation
# movie-has-director Personnalité
# has-type hastype
# has-occupation No
# is-where hastype
# birth-place where is albert Steffen born
# birth-place hastype
# has-author hastype
# birth-place description
# is-where located in
# birth-place where is the relative between Victoria Principal and David Head
# birth-place hasoccupation
# has-occupation hastype
# is-where located in
# has-occupation No
# org-has-member hasspouse
# birth-place instance of
# has-type hastype
# is-where No
# movie-has-director hasspouse
# from-country No
# has-author hastype
# birth-place hastype
# has-type Yes
# birth-place Haswife best describes the relation between Matt Bevin and Kentucky
# birth-place hasspouse
# has-type hastype
# birth-place location in
# birth-place hasspouse
# has-genre hastype
# is-where No
# is-where hastype
# has-spouse hasoccupation
# is-where No
# birth-place hastype
# birth-place located in
# birth-place where is the movie where is john fielding
# has-genre hastype
# birth-place hasoccupation
# birth-place Person in a given location
# birth-place No
# birth-place located in
# has-occupation hasoccupation
# from-country relationship
# is-member-of hasoccupation
# birth-place where is Neil Aggett born
# has-occupation hastype
# birth-place located in
# has-occupation hasoccupation
# is-where hastype
# has-type hastype
# movie-has-director hasspouse
# birth-place hastype
# has-occupation hasoccupation
# is-where hastype
# has-occupation hasoccupation
# movie-has-director has spouse
# has-genre hastype
# org-has-founder hasoccupation
# is-where No
# birth-place Where does Fredric Brown live
# has-author hastype
# has-occupation hastype
# has-type hastype
# birth-place No
# movie-has-director Personnages
# movie-has-director hasoccupation
# has-edu hastype
# has-occupation hasoccupation
# has-type hastype
# has-occupation hastype
# has-occupation hasoccupation
# has-occupation hasoccupation
# org-leader hasoccupation
# no_relation Hastype
# birth-place hastype
# birth-place hastype
# has-type Relationship
# is-where No
# org-has-founder hastype
# is-where hastype
# birth-place located in
# has-type hastype
# birth-place hastype
# birth-place hasoccupation
# has-type hasoccupation
# from-country hasoccupation
# is-where hasoccupation
# birth-place hastype
# from-country No
# is-where located in
# org-has-member hasspouse
# birth-place No
# is-where hastype
# birth-place located in
# no_relation No
# is-member-of hastype
# movie-has-director hasperson
# movie-has-director hasspouse
# movie-has-director Hasoccupation
# has-occupation hastype
# from-country hasoccupation
# birth-place hastype
# is-where No
# birth-place hastype
# has-type hastype
# birth-place hastype
# is-where No
# Results saved for en to fr
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasoccupation
# has-population haspopulation
# has-occupation hastype
# has-population haspopulation
# has-occupation hastype
# has-occupation hasparent
# has-type hasgenre
# has-edu havesex
# has-population haspopulation
# has-population hastype
# has-occupation hasgenre
# has-type hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# no_relation hasgenre
# has-population haspopulation
# has-type hasgenre
# has-population hasgenre
# has-type hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-type hasgenre
# has-population haspopulation
# has-type hastype
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-type hasgenre
# has-occupation hasgenre
# no_relation hasgenre
# has-occupation hasgenre
# has-occupation hasgender
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-population haspopulation
# has-genre hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-population haspopulation
# has-population haspopulation
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasoccupation
# has-population haspopulation
# has-population hasgenre
# has-genre hasgenre
# has-occupation hasgenre
# has-occupation hastype
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-type hasgenre
# has-population haspopulation
# has-occupation hasgenre
# has-occupation hasgenre
# has-population hasvolume
# has-genre hasgenre
# has-type hasgenre
# has-type hasgenre
# has-population haspopulation
# event-year hasgenre
# has-occupation hasgenre
# has-occupation hasoccupation
# has-occupation hasgenre
# has-type hasgenre
# has-occupation hasgenre
# has-population haspopulation
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hastype
# has-type hastype
# has-occupation hasgenre
# has-occupation hastype
# has-population hastype
# has-genre hasgenre
# has-occupation hasgenre
# has-population haspopulation
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-type instance of
# has-population hasgenre
# has-occupation hastype
# has-type hasgenre
# has-occupation hasgenre
# has-type hastype
# has-type hasparent
# has-population haspopulation
# event-year hasdate
# has-occupation hasgenre
# no_relation hasgenre
# has-genre has genre
# has-occupation hasgenre
# has-type hasgenre
# has-occupation hasgenre
# has-occupation hasoccupation
# has-type hasgenre
# has-population haspopulation
# has-type hasgenre
# has-occupation hasgenre
# has-genre hasgenre
# has-type hasgenre
# has-type hasgenre
# event-year date of award
# has-population hasgenre
# has-occupation hasgenre
# has-occupation hasgenre
# has-occupation haveparent
# has-occupation hasgenre
# has-occupation hasgenre
# has-genre has genre
# has-occupation hasgenre
# has-genre hasgenre
# has-population haspopulation
# has-occupation hasgenre
# has-type hasgenre
# has-occupation hasgenre
# has-population haspopulation
# has-occupation occupation
# has-population haspopulation
# has-occupation hasgenre
# Results saved for en to ru
# has-type Yes
# from-country Country
# is-where a first product
# birth-place relationship
# is-where relationship
# is-where Yes
# org-has-member pianist
# birth-place Yes
# from-country country
# has-type hasoccupation
# has-author hasoccupation
# birth-place a city
# birth-place birthplace
# is-where a occupation
# is-where occupation
# has-author iswhere
# movie-has-director relationship
# headquarters relative
# headquarters relationship
# has-author No
# headquarters iswhere
# is-where iswhere
# has-occupation hasoccupation
# has-genre relationship
# has-author relationship
# has-type No
# has-population a population
# org-has-member occupation
# movie-has-director birthplace
# has-population iswhere
# has-genre No
# movie-has-director hasoccupation
# has-occupation hasoccupation
# has-author instance of
# has-type No
# is-where No
# birth-place relation
# from-country a first product
# from-country No
# org-has-member hasoccupation
# is-member-of Relationship
# birth-place hasoccupation
# has-edu No
# has-edu a masters degree
# is-where iswhere
# headquarters languages spoken in Estonia
# org-has-member occupation
# is-where No
# has-author iswhere
# from-country relationship
# has-type hasoccupation
# has-author relationship
# is-where No
# has-child relationship
# has-occupation hasoccupation
# birth-place place of birth
# birth-place Yes
# is-member-of youth product
# birth-place iswhere
# is-where relations
# has-genre hasoccupation
# is-member-of hasoccupation
# has-edu relationship
# has-author hasoccupation
# headquarters No
# birth-place political party
# is-member-of No
# is-where No
# from-country No
# has-occupation hasoccupation
# org-has-member hasoccupation
# is-where Yes
# has-population list of relations
# headquarters Location
# won-award Relationship
# from-country Yes
# has-author hasoccupation
# has-type The relation is defined as a shared domain
# has-genre No
# from-country hasoccupation
# has-edu hasoccupation
# has-population Yes
# has-type instance of
# org-has-member brothers
# no_relation not in context
# birth-place iswhere
# has-sibling Sister
# movie-has-director hasoccupation
# has-sibling relationship
# birth-place No
# has-type hasoccupation
# has-spouse hasoccupation
# has-edu hasoccupation
# has-type hasoccupation
# has-occupation iswhere
# org-has-member relations
# has-author hasoccupation
# from-country No
# event-year Yes
# has-occupation occupation
# has-occupation iswhere
# org-has-member relationship
# birth-place iswhere
# has-author relationship
# from-country No
# has-type birthplace
# has-type No
# is-where iswhere
# headquarters iswhere
# org-has-founder Relationship
# org-has-member relations
# has-occupation relationship
# is-where a birth place
# org-has-member hasoccupation
# has-type Yes
# has-author birthplace
# org-has-member hasoccupation
# has-occupation hasoccupation
# has-parent a child
# has-occupation Relationship
# has-author relations
# from-country hasoccupation
# birth-place relations
# headquarters First product
# has-type iswhere
# has-author hasoccupation
# is-where No
# has-occupation relationship
# has-edu No
# has-author hasoccupation
# has-genre Yes
# has-occupation occupation
# has-author occupation
# org-has-member hasoccupation
# has-genre No
# has-population inequality
# has-author authors
# has-occupation hasoccupation
# from-country No
# has-type hasoccupation
# birth-place hasoccupation
# movie-has-director hasoccupation
# has-edu affiliation
# birth-place iswhere
# has-genre Relationship
# is-where No
# has-spouse relationship
# is-where Yes
# has-population No
# has-occupation hasoccupation
# org-has-member hasoccupation
# headquarters No
# has-type hasoccupation
# birth-place iswhere
# org-leader The Banga Sena is a separatist Hindu organization which advocates formation of a separate homeland for Bengali Hindus in Bangladesh The group is headquartered in Metz The group has a member of the organization which is headquartered in Metz
# has-genre No
# has-population No
# has-population No
# org-has-founder significant
# has-population No
# from-country occupation
# has-author relationship
# has-child occupation
# org-has-member hasoccupation
# has-occupation hasoccupation
# org-has-founder relationship
# headquarters No
# won-award hasoccupation
# org-has-founder a parent
# birth-place No
# headquarters iswhere
# has-population population
# is-where iswhere
# first-product No
# from-country occupation
# has-sibling iswhere
# birth-place lieu de naissance
# has-type hasoccupation
# birth-place relations
# has-genre No
# has-type instance of
# has-author Relationship
# has-type relationship
# birth-place birthplace
# has-type No
# headquarters No
# is-where relationship
# is-where Yes
# has-population population
# has-type No
# from-country No
# org-leader Relationship
# has-author iswhere
# is-where country
# movie-has-director relationship
# birth-place relations
# starring hasoccupation
# org-has-founder relationship
# won-award hasoccupation
# movie-has-director relations
# Results saved for fr to en
# has-occupation hasauthor
# has-occupation hasauthor
# has-occupation a pour auteur
# has-population haspopulation
# has-occupation a pour auteur
# has-population haspopulation
# has-occupation hasperson
# has-occupation hasauthors
# has-type hasrelation
# has-edu Iton
# has-population haspopulation
# has-population iswhere
# has-occupation a une éducation
# has-type haswriter
# has-occupation a pour auteur
# has-occupation hasauthor
# has-occupation a pour auteur
# no_relation hasauthor
# has-population haspopulation
# has-type a une relation
# has-population a un type
# has-type relations
# has-occupation a une occupation
# has-occupation sur le plan de léducation
# has-type a une relation
# has-population haspopulation
# has-type iswhere
# has-occupation hasauthor
# has-occupation a une occupation
# has-occupation A un genre
# has-occupation iswhere
# has-type haspopulation
# has-occupation relations
# no_relation a une éducation
# has-occupation a une éducation
# has-occupation Personnalité
# has-occupation a pour auteur
# has-occupation a une éducation
# has-occupation a une éducation
# has-occupation hasauthor
# has-occupation relations
# has-population haspopulation
# has-genre a une éducation
# has-occupation a une occupation
# has-occupation atype
# has-population haspopulation
# has-population haspopulation
# has-occupation hasauthor
# has-occupation a une éducation
# has-occupation a une relation
# has-occupation Personnalité
# has-occupation a une relation
# has-population haspopulation
# has-population hasrelation
# has-genre hasrelation
# has-occupation a une occupation
# has-occupation a une occupation
# has-occupation a une occupation
# has-occupation a une occupation
# has-occupation hasauthor
# has-type a une relation
# has-population haspopulation
# has-occupation a une occupation
# has-occupation relation
# has-population haspopulation
# has-genre a une éducation
# has-type décrit le mieux la relation entre
# has-type a éducation
# has-population haspopulation
# event-year a une éducation
# has-occupation hasauthor
# has-occupation a pour auteur
# has-occupation a une relation
# has-type a une relation
# has-occupation a a une éducation
# has-population haspopulation
# has-occupation a une relation
# has-occupation a une éducation
# has-occupation occupation
# has-occupation relation
# has-type hasrelation
# has-occupation Yes
# has-occupation a une relation
# has-population haspopulation
# has-genre notable
# has-occupation a un type
# has-population haspopulation
# has-occupation a pour auteur
# has-occupation hasdate
# has-occupation a une relation
# has-type a une relation
# has-population haspopulation
# has-occupation a une occupation
# has-type a une relation
# has-occupation hasauthor
# has-type Deux entités peuvent exister dans un domaine
# has-type a pour auteur
# has-population haspopulation
# event-year date de naissance
# has-occupation a une relation
# no_relation return
# has-genre a un genre
# has-occupation a pour auteur
# has-type hasrelation
# has-occupation a pour auteur
# has-occupation A une relation
# has-type hasauthor
# has-population haspopulation
# has-type hasauthor
# has-occupation a une relation
# has-genre genre
# has-type a une éducation
# has-type hasrelation
# event-year date de lévénement
# has-population haspopulation
# has-occupation a pour auteur
# has-occupation hasauthor
# has-occupation a pour auteur
# has-occupation occupation
# has-occupation iswhere
# has-genre a un genre
# has-occupation occupation
# has-genre a une activité
# has-population haspopulation
# has-occupation occupation
# has-type a un type
# has-occupation a une relation
# has-population a une population
# has-occupation a pour auteur
# has-population haspopulation
# has-occupation a pour auteur
# Results saved for fr to ru
# birth-place Étudiez le sujet
# has-type hasoccupation
# movie-has-director hasoccupation
# has-occupation hasoccupation
# movie-has-director hasoccupation
# birth-place lieu de naissance
# has-genre instances
# birth-place lieu de naissance
# birth-place rintx for x in inputsplit r  rsplit r  rsplit r  rsplit r  rsplit r  rsplit r  rsplit r  rsplit r  rsplit r  rsplit r
# birth-place lieu de naissance
# has-genre instances
# birth-place hasoccupation
# movie-has-director hasoccupation
# has-occupation hasoccupation
# has-type hasoccupation
# birth-place hasoccupation
# has-author hasoccupation
# has-occupation hasoccupation
# has-occupation hasoccupation
# from-country hasoccupation
# birth-place lieu de naissance
# has-type hasoccupation
# birth-place Yes
# is-where hasoccupation
# is-where hasoccupation
# movie-has-director hasoccupation
# is-where Yes
# birth-place lieu de naissance
# movie-has-director hasoccupation
# has-author hasoccupation
# has-genre Yes
# org-has-member hasoccupation
# has-author hasoccupation
# has-occupation hasoccupation
# event-year lieu de naissance
# headquarters hasoccupation
# has-type hasoccupation
# is-where A
# birth-place lieu de naissance
# movie-has-director hasoccupation
# has-parent hasoccupation
# has-occupation hasoccupation
# movie-has-director hasoccupation
# is-where hasoccupation
# is-where lieu de naissance
# is-where hasoccupation
# birth-place lieu de naissance
# has-genre hasoccupation
# is-where hasoccupation
# is-where hasoccupation
# movie-has-director hasoccupation
# birth-place hasoccupation
# movie-has-director hasoccupation
# movie-has-director hasoccupation
# is-where hasoccupation
# has-occupation hasoccupation
# birth-place No
# birth-place hasoccupation
# birth-place lieu de naissance
# birth-place No
# has-author hasoccupation
# movie-has-director hasoccupation
# from-country Yes
# birth-place No
# birth-place lieu de naissance
# birth-place lieu de naissance
# birth-place Le lieu de naissance
# has-type hasoccupation
# birth-place hasoccupation
# birth-place lieu de naissance
# movie-has-director hasoccupation
# is-member-of hasoccupation
# birth-place Nom de la ville
# movie-has-director hasoccupation
# has-type hasoccupation
# birth-place lieu de naissance
# has-genre hasoccupation
# has-occupation ispersonnel
# has-genre s  inconnuevalues   for i in rangelens if si  si  1 and si  1  si  1 and si  1  si  1 and si  1  si  1 and si  1  svalues
# birth-place No
# birth-place Sachez où se trouve la relation entre Juris Podnieks et Riga
# is-where hasoccupation
# birth-place lieu de naissance
# birth-place lieu de naissance
# has-occupation hasoccupation
# has-occupation hasoccupation
# has-genre instance
# birth-place lieu de naissance
# birth-place hasoccupation
# has-genre hasoccupation
# birth-place lieu de naissance
# birth-place hasoccupation
# birth-place No
# movie-has-director hasoccupation
# has-type instances
# has-occupation occupation
# is-where hasoccupation
# birth-place lieu de naissance
# birth-place hasoccupation
# has-author hasoccupation
# birth-place No
# is-where lieu de naissance
# birth-place No
# birth-place No
# has-occupation hasoccupation
# is-where hasoccupation
# has-occupation hasoccupation
# org-has-member occupation
# birth-place lieu de naissance
# has-type hasoccupation
# is-where lieu de naissance
# movie-has-director hasoccupation
# from-country No
# has-author hasoccupation
# birth-place lieu de naissance
# has-type instances
# birth-place instance
# birth-place lieu de naissance
# has-type hasoccupation
# birth-place Yes
# birth-place lieu de naissance
# has-genre Yes
# is-where hasoccupation
# is-where hasoccupation
# has-spouse hasoccupation
# is-where instances
# birth-place lieu de naissance
# birth-place No
# birth-place lieu de naissance
# has-genre Yes
# birth-place lieu de naissance
# birth-place lieu de naissance
# birth-place lieu de naissance
# birth-place lieu de naissance
# has-occupation hasoccupation
# from-country lieu de naissance
# is-member-of hasoccupation
# birth-place Nom de la personne
# has-occupation hasoccupation
# birth-place Le nom de la région où lassociation a été fondée a été défini par une relation est
# has-occupation hasoccupation
# is-where hasoccupation
# has-type hasoccupation
# movie-has-director hasoccupation
# birth-place lieu de naissance
# has-occupation hasoccupation
# is-where hasoccupation
# has-occupation hasoccupation
# movie-has-director hasoccupation
# has-genre Yes
# org-has-founder No
# is-where hasoccupation
# birth-place Nom donné
# has-author hasoccupation
# has-occupation hasoccupation
# has-type hasoccupation
# birth-place lieu de naissance
# movie-has-director Personnalité
# movie-has-director hasoccupation
# has-edu instances
# has-occupation hasoccupation
# has-type hasoccupation
# has-occupation hasoccupation
# has-occupation hasoccupation
# has-occupation hasoccupation
# org-leader hasoccupation
# no_relation hasoccupation
# birth-place hasoccupation
# birth-place No
# has-type hasoccupation
# is-where hasoccupation
# org-has-founder hasoccupation
# is-where hasoccupation
# birth-place Yes
# has-type hasoccupation
# birth-place lieu de naissance
# birth-place No
# has-type occupation
# from-country Yes
# is-where hasoccupation
# birth-place Yes
# from-country Yes
# is-where hasoccupation
# org-has-member hasoccupation
# birth-place lieu de naissance
# is-where hasoccupation
# birth-place Declaration
# no_relation No
# is-member-of hasoccupation
# movie-has-director hasoccupation
# movie-has-director hasoccupation
# movie-has-director hasoccupation
# has-occupation hasoccupation
# from-country hasoccupation
# birth-place Le lieu de naissance de Houssine Dimassi
# is-where hasoccupation
# birth-place lieu de naissance
# has-type instances   for i in rangei instancesappendi
# birth-place hasoccupation
# is-where hasoccupation
# Results saved for ru to fr
# has-type hasoccupation
# from-country hasoccupation
# is-where hasoccupation
# birth-place hasoccupation
# is-where hasoccupation
# is-where hasoccupation
# org-has-member hasoccupation
# birth-place hasoccupation
# from-country hasoccupation
# has-type hastype
# has-author hastype
# birth-place country of origin
# birth-place hasoccupation
# is-where hasoccupation
# is-where city
# has-author hasoccupation
# movie-has-director hasoccupation
# headquarters hasoccupation
# headquarters hasoccupation
# has-author hasoccupation
# headquarters hasoccupation
# is-where hastype
# has-occupation hasoccupation
# has-genre hasoccupation
# has-author hasoccupation
# has-type hastype
# has-population hastype
# org-has-member hasoccupation
# movie-has-director hasoccupation
# has-population hasoccupation
# has-genre hasoccupation
# movie-has-director hasoccupation
# has-occupation hasoccupation
# has-author hasoccupation
# has-type hastype
# is-where hasoccupation
# birth-place place of birth
# from-country hasoccupation
# from-country Yes
# org-has-member hasoccupation
# is-member-of hasoccupation
# birth-place hasoccupation
# has-edu hasoccupation
# has-edu hasoccupation
# is-where hasoccupation
# headquarters country
# org-has-member hasoccupation
# is-where hasoccupation
# has-author hasoccupation
# from-country hasoccupation
# has-type hasoccupation
# has-author hasoccupation
# is-where Hasoccupation
# has-child hasoccupation
# has-occupation hasoccupation
# birth-place hasoccupation
# birth-place hasoccupation
# is-member-of hastype
# birth-place hastype
# is-where country
# has-genre hasoccupation
# is-member-of hasoccupation
# has-edu hasoccupation
# has-author hasoccupation
# headquarters hasoccupation
# birth-place located in
# is-member-of hasoccupation
# is-where hasoccupation
# from-country country of citizenship
# has-occupation hasoccupation
# org-has-member hasoccupation
# is-where hastype
# has-population hastype
# headquarters hasoccupation
# won-award hasoccupation
# from-country hasoccupation
# has-author hasoccupation
# has-type hasoccupation
# has-genre hastype
# from-country hasoccupation
# has-edu hasoccupation
# has-population hastype
# has-type hastype
# org-has-member hasoccupation
# no_relation hasoccupation
# birth-place hasoccupation
# has-sibling hasoccupation
# movie-has-director hasoccupation
# has-sibling hasoccupation
# birth-place located in
# has-type hastype
# has-spouse hasoccupation
# has-edu hasoccupation
# has-type hastype
# has-occupation hasoccupation
# org-has-member hasoccupation
# has-author hasoccupation
# from-country hasoccupation
# event-year hasoccupation
# has-occupation hasoccupation
# has-occupation hasoccupation
# org-has-member hasoccupation
# birth-place hasoccupation
# has-author hasoccupation
# from-country hasoccupation
# has-type hastype
# has-type hastype
# is-where hasoccupation
# headquarters hasoccupation
# org-has-founder hasoccupation
# org-has-member hasoccupation
# has-occupation hasoccupation
# is-where hasoccupation
# org-has-member hasoccupation
# has-type hastype
# has-author hasoccupation
# org-has-member hasoccupation
# has-occupation hasoccupation
# has-parent hasoccupation
# has-occupation hasoccupation
# has-author hasoccupation
# from-country hasoccupation
# birth-place hasoccupation
# headquarters hasoccupation
# has-type hasoccupation
# has-author hasoccupation
# is-where hastype
# has-occupation hasoccupation
# has-edu hasoccupation
# has-author hasoccupation
# has-genre hasoccupation
# has-occupation hasoccupation
# has-author hasoccupation
# org-has-member hasoccupation
# has-genre hastype
# has-population hastype
# has-author hasoccupation
# has-occupation hasoccupation
# from-country hasoccupation
# has-type hastype
# birth-place hasoccupation
# movie-has-director hasoccupation
# has-edu hasoccupation
# birth-place hasoccupation
# has-genre hasoccupation
# is-where country
# has-spouse hasoccupation
# is-where hasoccupation
# has-population hasoccupation
# has-occupation hasoccupation
# org-has-member hasoccupation
# headquarters hasoccupation
# has-type hastype
# birth-place Yes
# org-leader hasoccupation
# has-genre hasoccupation
# has-population hasoccupation
# has-population hasoccupation
# org-has-founder hasoccupation
# has-population hastype
# from-country hasoccupation
# has-author hasoccupation
# has-child hasoccupation
# org-has-member hasoccupation
# has-occupation hasoccupation
# org-has-founder hasoccupation
# headquarters hasoccupation
# won-award hasoccupation
# org-has-founder hasoccupation
# birth-place place of birth
# headquarters hasoccupation
# has-population hastype
# is-where hasoccupation
# first-product hasoccupation
# from-country hasoccupation
# has-sibling hasoccupation
# birth-place hasoccupation
# has-type hasoccupation
# birth-place Location
# has-genre hastype
# has-type hasoccupation
# has-author hasoccupation
# has-type hasoccupation
# birth-place hasoccupation
# has-type hastype
# headquarters hasoccupation
# is-where hasoccupation
# is-where hasoccupation
# has-population hastype
# has-type hastype
# from-country hasoccupation
# org-leader hasoccupation
# has-author hasoccupation
# is-where country
# movie-has-director hasoccupation
# birth-place hastype
# starring hasoccupation
# org-has-founder hasoccupation
# won-award hasoccupation
# movie-has-director hasoccupation
# Results saved for ru to en
