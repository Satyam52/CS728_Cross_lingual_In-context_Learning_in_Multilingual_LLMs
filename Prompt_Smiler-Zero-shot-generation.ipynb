# %%
# !apt-get install p7zip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# !wget https://github.com/samsungnlp/smiler/raw/main/smiler_corpora_v1.0_part1.7z
# !7z e smiler_corpora_v1.0_part1.7z
# Out:
# --2024-05-02 05:11:16--  https://github.com/samsungnlp/smiler/raw/main/smiler_corpora_v1.0_part1.7z
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/samsungnlp/smiler/main/smiler_corpora_v1.0_part1.7z [following]
# --2024-05-02 05:11:16--  https://raw.githubusercontent.com/samsungnlp/smiler/main/smiler_corpora_v1.0_part1.7z
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28929993 (28M) [application/octet-stream]
# Saving to: ‘smiler_corpora_v1.0_part1.7z’
#
# smiler_corpora_v1.0 100%[===================>]  27.59M  11.5MB/s    in 2.4s
#
# 2024-05-02 05:11:19 (11.5 MB/s) - ‘smiler_corpora_v1.0_part1.7z’ saved [28929993/28929993]
#
# /bin/bash: line 1: 7z: command not found

# %%
SMILER_TRANSLATE = {
    "en": {
        "birth-place": "birth place",
        "eats": "eats",
        "event-year": "event year",
        "first-product": "first product",
        "from-country": "from country",
        "has-author": "has author",
        "has-child": "has child",
        "has-edu": "has education",
        "has-genre": "has genre",
        "has-height": "has height",
        "has-highest-mountain": "has highest mountain",
        "has-length": "has length",
        "has-lifespan": "has lifespan",
        "has-nationality": "has nationality",
        "has-occupation": "has occupation",
        "has-parent": "has parent",
        "has-population": "has population",
        "has-sibling": "has sibling",
        "has-spouse": "has spouse",
        "has-tourist-attraction": "has tourist attraction",
        "has-type": "has type",
        "has-weight": "has weight",
        "headquarters": "headquarters",
        "invented-by": "invented by",
        "invented-when": "invented when",
        "is-member-of": "is member of",
        "is-where": "located in",
        "loc-leader": "location leader",
        "movie-has-director": "movie has director",
        "no_relation": "no relation",
        "org-has-founder": "organization has founder",
        "org-has-member": "organization has member",
        "org-leader": "organization leader",
        "post-code": "post code",
        "starring": "starring",
        "won-award": "won award",
    },
    "fr": {
        "birth-place": "lieu de naissance",
        "event-year": "année de l'événement",
        "from-country": "du pays",
        "has-author": "a un auteur",
        "has-child": "a un enfant",
        "has-edu": "a une éducation",
        "has-genre": "a un genre",
        "has-occupation": "a une profession",
        "has-parent": "a un parent",
        "has-population": "a de la population",
        "has-spouse": "a un conjoint",
        "has-type": "a le type",
        "headquarters": "siège social",
        "is-member-of": "est membre de",
        "is-where": "situé à",
        "loc-leader": "guide d'emplacement",
        "movie-has-director": "le film a un réalisateur",
        "no_relation": "aucune relation",
        "org-has-founder": "l'organisation a un fondateur",
        "org-has-member": "l'organisation a un membre",
        "org-leader": "chef d'organisation",
        "won-award": "a remporté le prix",
    },
    "ru": {
        "event-year": "год события",
        "has-edu": "имеет образование",
        "has-genre": "имеет жанр",
        "has-occupation": "имеет профессию",
        "has-population": "имеет население",
        "has-type": "имеет тип",
        "is-member-of": "является членом",
        "no_relation": "без связи",
    }
}

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, AutoModelForCausalLM 
class args:
    tgt_num = 200 # First 200 examples from the target language
    src_num = -1 # NO examples from the source language
    max_new_tokens = 100
    temperature = 0.6
    device="cuda:0"
    l1 = "en"
    l2 = "fr"
    l3 = "ru"

tokenizer = AutoTokenizer.from_pretrained("bigscience/mt0-large")
model = AutoModelForSeq2SeqLM.from_pretrained("bigscience/mt0-large").to(args.device)

# %%
## Script for creating a prompt for the user to enter a number
import json
import argparse
import csv
import os
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
# XGLMTokenizer, XGLMForCausalLM,
from tqdm import tqdm
import re


dir_path=""
prompt_template_zero = {
    "en": """
Consider the following statement as truth: {}.
What is the most appropriate relation between {} and {} from the following options?

{}

Please choose the most suitable option from the given choices.
    """,
# "en":"""
# {} Which of the following relations best describes the connection between {} and {}?
# Options:

# {}

# Provide your answer as the option mentioned above
# """,
    "fr":"""
Considérez l'énoncé suivant comme vérité : {}.
Quelle est la relation la plus appropriée entre {} et {} parmi les options suivantes ?

{}

Veuillez choisir l'option la plus appropriée parmi les choix donnés
    """,
    "ru":"""
Рассматривайте следующее утверждение как истинное: {}.
Какое из следующих отношений наиболее подходит для описания связи между {} и {}?

{}

Пожалуйста, выберите наиболее подходящий вариант из предложенных
    """
}

prompt_template_example = """
Consider the following statement as truth: {}'
What is the most appropriate relation between {} and {} from the following options?

{}

Please choose the most suitable option from the given choices.

Examples:
{}

"""



def create_examples(src, tgt, num, choices):
    if num == -1:
        return prompt_template_zero[tgt]

    with open(dir_path + f"{lang}_corpora_train.tsv", "r") as f:
        reader = csv.reader(f, delimiter="\t")
        examples = ""
        for i, row in enumerate(reader):
            if i < 1:
                continue
            if i > num:
                break
            sen = row[4]
            sen = sen.replace("<e1>", "").replace("</e1>", "").replace("<e2>", "").replace("</e2>", "")
            e1 = row[4].split("<e1>")[1].split("</e1>")[0]
            e2 = row[4].split("<e2>")[1].split("</e2>")[0]
            sen = "{{"+sen+"}}"

            examples += "For statement {}: {} is related to {} as: {}\n".format(sen, e1, e2, row[3])

        prompt_template_example.format("{}", "{}", "{}", "{}", examples)
        return examples



def inference(prompt, max_new_tokens=args.max_new_tokens, temperature=args.temperature):


    model_inputs = tokenizer([prompt], return_tensors="pt").to(args.device)

    # For removal of input string from the output string
    input_ids_cutoff = model_inputs.input_ids.size(dim=1)

    generated_ids = model.generate(**model_inputs,
                                   max_new_tokens=max_new_tokens,
                                   top_p = 1,
                                   temperature = temperature,
                                  #  num_beams=20,
                                   do_sample=True,
                                   pad_token_id=tokenizer.eos_token_id)

    completion = tokenizer.decode(
    generated_ids[0],
    skip_special_tokens=True)

    return completion


def create_rel_vocab(src_lang, tgt_lang, src_num, tgt_num):
    relations = set()

    # Iterate src
    with open(dir_path + f"{src_lang}_corpora_train.tsv", "r") as f:
        reader = csv.reader(f, delimiter="\t")
        for i, row in enumerate(reader):
            if i < 1:
                continue
            if i > src_num:
                break
            relations.add(f"{row[3]}")

    # Iterate tgt
    with open(dir_path + f"{tgt_lang}_corpora_test.tsv", "r") as f:
        reader = csv.reader(f, delimiter="\t")
        for i, row in enumerate(reader):
            if i < 1:
                continue
            if i > tgt_num:
                break
            rel = "{{"+SMILER_TRANSLATE[tgt_lang][row[3]]+"}}"
            relations.add(f'{rel}')
            # relations.add(f'"{row[3]}"')

    return relations


def main():

    for lang1 in [args.l2]:
        for lang2 in [args.l3]:
            actual_result = []
            gen_result = []

            if lang1 == lang2:
                continue

            # Create relation vocabulary
            choices = create_rel_vocab(lang1, lang2, args.src_num, args.tgt_num)

            # If not zero-shot, create examples
            prompt_src = create_examples(lang1, lang2, args.src_num, choices)

            os.makedirs(f"{lang1}_{lang2}", exist_ok=True)
            # Create prompt for each example and save it
            with open(dir_path + f"{lang2}_corpora_test.tsv", "r") as f:
                reader = csv.reader(f, delimiter="\t")
                for i, row in enumerate(reader):
                    if i < 1:
                        continue
                    if i > args.tgt_num:
                        break
                    # if f'"{SMILER_TRANSLATE[lang2][row[3]]}"' not in choices:
                    # # if f'"{row[3]}"' not in choices:
                    #     raise ValueError(f"Relation {row[3]} not in the relation vocabulary {lang2}")

                    sen = row[4]
                    sen = sen.replace("<e1>", "").replace("</e1>", "").replace("<e2>", "").replace("</e2>", "")
                    e1 = row[4].split("<e1>")[1].split("</e1>")[0]
                    e2 = row[4].split("<e2>")[1].split("</e2>")[0]
                    sen = "{{"+sen+"}}"
                    e1 = "{{"+e1+"}}"
                    e2 = "{{"+e2+"}}"
                    prompt = prompt_src.format(sen, e1, e2, "\n".join(choices))
                    result = inference(prompt)
                    # Clean the result
                    result = re.sub(r"[!@#$%^&*()_+\-=[\]{};':,.<>/?\\|~]", "", result)
                    # Also remove all quotes
                    result = result.replace('"', "").replace("'", "").replace("`", "")
                    # result = next((key for key, value in SMILER_TRANSLATE[lang2].items() if value == result), result)

                    print(row[3], result)
                    
                    with open(f"{lang1}_{lang2}/prompt_{i}.txt", "w") as f:
                        f.write(prompt)

                    actual_result.append(SMILER_TRANSLATE[lang2][row[3]])
                    gen_result.append(result)

            df = pd.DataFrame({"actual": actual_result, "generated": gen_result})
            df.to_csv(f"{lang1}_{lang2}/results.tsv", sep="\t", index=False)
            print(f"Results saved for {lang1} to {lang2}")


main()
# Out:
# has-occupation अभिनेत्री
# has-occupation  birth date is 14 september 1973  occupation is singer musician producer actor entrepreneur  birth place is Brooklyn New York United States
# has-occupation director
# has-population No
# has-occupation  known for is a British musician He is a British musician He is a British composer and songwriter He is best known for his work in the theatre theatre and theatre
# has-population Yes
# has-occupation  yearsactive is 2005  occupation is actor  birth place is hollywood california
# has-occupation  occupation is a religious critic
# has-type  known for is knight  birth date is 13 juin 1928  nationality is italy  death date is 11 July 2015  birth place is bologna italy  name is carlo fascista
# has-edu
# has-population Yes
# has-population а а
# has-occupation  fields  电影 cinema cinema film cinema cinema  birth date  occupation  death date  birth place  name
# has-type năm
# has-occupation  name
# has-occupation  yearsactive is 1981  present  birth date is 8 august 1958  occupation is actor  birth place is buenosaries aRGENTINA  name is sesilia rothenberg roth  associated acts is atalanta atalanta
# has-occupation  known for is a writer  birth date is 27  june 1872  nationality is afroamerican  death date is 10 February 1906  genre is novels novels poetry  occupation is writer  death place is washington dc
# no_relation  19251922  19221922  Opusoшение  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922  19221922
# has-population
# has-type  Бата  Уэлса 1275—1292 избранный архиепископ Кентерберийский 1278—1279
# has-population 1203
# has-type
# has-occupation  yearsactive is 2002  present  birth date is 28 February 1970  occupation is actor  birth place is miami florida us  name is tangi miller
# has-occupation
# has-type instanceofdeath
# has-population time
# has-type  Cardinal Доменико Кальканьо  Cardinal  Cardinal Доменико Кальканьо  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal  Cardinal
# has-occupation Yes
# has-occupation  ˈliːnda
# has-occupation  known for is a composer composer writer composer composer writer composer composer writer composer composer writer composer composer composer composer
# has-occupation
# has-type include bitsstdch using namespace std int main  int t cin  t while t  long long int n cin  n long long int an for int i  0 i  n i  cin  ai  sorta a  n
# has-occupation  known for is religious religious worker philosopher antiquarian writer canonicalist  birth date is 11 december 1529  death date is 18 may 1600  birth place is rome italy  name is fo orsini
# no_relation instances
# has-occupation   27 augusta 1870 Tepik штат Nayarit Meksika  24 may 1919 Montevideo Uruguay
# has-occupation occupation
# has-occupation Artist
# has-occupation  known for is a composer born in BuenosAires a Argentine born in 1933  known for is a composer  birth date is 30 august 1933  occupation is musician composer  death date is 15 november 2017  genre is romantic music  birth place is buenosaires aRGENTINA  name is Louis Bacалов  death place
# has-occupation Artist
# has-occupation Film director
# has-occupation  known for is a writers circle He is a publisher editor orator author He is a translator and a teacher
# has-population iddataidididid
# has-genre s0
# has-occupation  known for is actressactress  birth date is 10 may 1947  nationality is american  occupation is actor actress  birth place is filthdelphia pennsylvania  name is maryan ramsi
# has-occupation कला
# has-population
# has-population Yes
# has-occupation  known for is dance theatre and theatre
# has-occupation born 24 January 1986 in London
# has-occupation aname
# has-occupation  known for is Danish Melodi Grand Prix 2008 she won the Danish Melodi Grand Prix 2008 and had an opportunity to represent Dania at the 2008 Eurovision Song Contest  yearsactive is 2008  present  birth date is 29 September 1959  occupation is singer  birth place is Malmö Sweden  name is Saymon M M
# has-occupation lawyer
# has-population  Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg Fraynberg
# has-population Место рождения
# has-genre дата события
# has-occupation  year
# has-occupation
# has-occupation  known for is starring  birth name is Juan Manuel Bernal  occupation is actor  birth date is 22 december 1967  occupation is actor  genre is theatre  birth place is mexico city mexico  name is huamán manuel bernardo
# has-occupation  yearsactive is 1949  present  birth date is 30 novembre 1938  occupation is film operator  genre is film television film television film television film television film television film television film television film television film television film  birth place is krakow poland  name is adam griffin
# has-occupation Yes
# has-type  known for is a cardinal
# has-population отношения
# has-occupation o
# has-occupation  imdb urnabsimdbcom
# has-population село
# has-genre genre
# has-type  NGC 4308
# has-type лётчик
# has-population 1781
# event-year  date of events
# has-occupation  occupation is actor
# has-occupation  name name
# has-occupation  background is nonvocalinstrumentalist  birth date is 8 september 1990  label is records  website is lsb httpwwwmyspacecomjamesvanberg  occupation is musician  genre is rock pop punk rock band  years active is 1996  present  genre is rock punk electronic  name is jey bayernberg
# has-type  Joe
# has-occupation  known for is Charlie Reed and Charlie Reed  birth date is 11  june 1977  occupation is actor singer  death date is 20 juin 2011  birth place is Медина Oahu united states  name is Rayan Dann
# has-population
# has-occupation  name is Nikolai Arsel
# has-occupation  imdb nimdb  birth date  occupation  death date  birth place  name  death place
# has-occupation musical
# has-occupation  fields is zoology  birth date is 03 october 1830  nationality is german  occupation is zoologist  death date is 14 october 1914  birth place is eastern germany  name is albert gunter
# has-type instance
# has-occupation  birth date is unknown  occupation is television personality presenter actor  birth place is us us
# has-occupation relationships
# has-population Yes
# has-genre Yes
# has-occupation  occupation is film director
# has-population
# has-occupation  yearsactive is 1978  present  birth date is 29 august 1941  occupation is actor professor screenwriter  birth place is brooklyn new york us  name is ell g
# has-occupation  residence is london
# has-occupation  yearsactive is 1990  present  birth date is 20 may 1958  occupation is actor  birth place is washington dc us  name is mett mackay
# has-type  known for is a Catholic priest  known for is a priest lrb c 1993 rrb a Catholic priest lrb c 1993 rrb  birth date is 7 august 1993  nationality is austrian  occupation is priest  genre is catholicism  birth place is italy  name is reg
# has-population село
# has-occupation о  Исполнитель
# has-type British
# has-occupation  occupation is film director screenwriter  years active is 1945  1996  birth date is 17  june 1927  occupation is film director screenwriter  death date is 13 marzo 1996  birth place is rome italy  name is l luca fUCLI
# has-type отношения
# has-type No
# has-population No
# event-year дата события
# has-occupation  fields is genus
# no_relation No
# has-genre  known for is a lyricist  name is paolo moji
# has-occupation year is 2000  occupation is director  birth place is yugoslavia  name is Душан Макавеев
# has-type No
# has-occupation
# has-occupation genre
# has-type и
# has-population No
# has-type Album
# has-occupation  yearsactive is 1993present  birth date is 9 july 1982  occupation is actor  birth place is tbilisi armenia  name is marjan avetASIN
# has-genre  known for is a famous singer and musician He is best known for his recordings which include a cappella musical compositions a cello a piano a cello a guitar
# has-type атоллы
# has-type  known for is city in germany  known for is city in the administrative district of southeastern germany  known for is city in germany
# event-year năm
# has-population 1379
# has-occupation  occupation is writer
# has-occupation  occupation is film director and screenwriter  birth date is 29  september 1932  nationality is american  occupation is film director screenwriter  genre is documentary film television television theater television television television film television television television film television  birth place is waxahachie texan us
# has-occupation  occupation is musician
# has-occupation
# has-occupation  known for is publisher editor writer publisher
# has-genre  known for is a british singersongwriter and composer  birth date is 1 october 1946  nationality is british  occupation is composer  years active is 1972  present  genre is british  name is Dewy Hollland
# has-occupation Artist
# has-genre  known for is a singersongwriter sax player cello player  birth date is 12 december 1933  label is gpop  occupation is musician songwriter songwriter songwriter  death date is 4 January 1991  genre is progressive progressive rock progressive rock progressive rock progressive rock
# has-population 797
# has-occupation include bitsstdch using namespace std int main  int i j n f scanfd n for i  0 i  n i  scanfd f a b if f  0 continue else  scanfd a b
# has-type  Год события
# has-occupation  yearsactive is 2013  present  birth date is 15 February 1998  occupation is actor  birth place is Oakland California  name is Zakari Gordon
# has-population
# has-occupation  known for is a rapper actor entrepreneur author film producer musician producer film director philanthropist
# has-population Yes
# has-occupation  imdb id
# Results saved for fr to ru
